# %%
from univariate import Uni_analysis

# %%
#importing libray and dataset
import pandas as pd
import numpy as np
dataset = pd.read_csv("50_Startups.csv")
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
Qual,Quan = Uni_analysis.qualquan(dataset)
print("Qual=",Qual)
print("Quan=",Quan)
# Out:
# Qual= ['State']
# Quan= ['R&D Spend', 'Administration', 'Marketing Spend', 'Profit']

# %%
table=pd.DataFrame()
table
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive = Uni_analysis.univariate_desc(dataset,Quan)
descriptive
# Out:
#                   R&D Spend Administration Marketing Spend       Profit
# Mean             73721.6156    121344.6396     211025.0978  112012.6392
# Median             73051.08     122699.795       212716.24    107978.19
# Mode                    0.0       51283.14             0.0      14681.4
# Q1:25%             39936.37     103730.875     129300.1325   90138.9025
# Q2:50%             73051.08     122699.795       212716.24    107978.19
# Q3:75%             101602.8      144842.18      299469.085  139765.9775
# 99%              164000.965    170419.2564     458120.1707  192031.6427
# Q4:100%            165349.2      182645.56        471784.1    192261.83
# IQR                61666.43      41111.305     170168.9525    49627.075
# 1.5 rule          92499.645     61666.9575    255253.42875   74440.6125
# Lesser Outlier   -52563.275     42063.9175   -125953.29625     15698.29
# Greater Outlier  194102.445    206509.1375    554722.51375    214206.59
# ...

# %%
lesser,greater=Uni_analysis.to_check_outliers(Quan,descriptive)
print("Lesser:",lesser)
print("Greater:",greater)
# Out:
# Lesser: ['Profit']
# Greater: []

# %%
dataset = Uni_analysis.to_replace_outlier(dataset, descriptive, lesser, greater)
print(dataset)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
freqtable=Uni_analysis.freqtable('Profit',dataset)
freqtable
# Out:
#     Unique_values  Frequancy  Relative_Freq  CumulativeFreq
# 0       192261.83          1           0.02            0.02
# 1        89949.14          1           0.02            0.04
# 2       105008.31          1           0.02            0.06
# 3       103282.38          1           0.02            0.08
# 4       101004.64          1           0.02            0.10
# 5        99937.59          1           0.02            0.12
# 6        97483.56          1           0.02            0.14
# 7        97427.84          1           0.02            0.16
# 8        96778.92          1           0.02            0.18
# 9        96712.80          1           0.02            0.20
# 10       96479.51          1           0.02            0.22
# 11       90708.19          1           0.02            0.24
# 12       81229.06          1           0.02            0.26
# 13      191792.06          1           0.02            0.28
# 14       81005.76          1           0.02            0.30
# ...
