# %%
# import dataset
import pandas as pd
dataset = pd.read_csv("placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace = True)

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.drop(columns = ["sl_no"],inplace = True)

# %%
dataset.isna().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
cov_matrix=dataset.cov()
cov_matrix
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      60.348373      42.897137      37.659225
# hsc_p         60.348373     118.755706      34.819820      35.461678
# degree_p      42.897137      34.819820      54.151103      21.929469
# etest_p       37.659225      35.461678      21.929469     176.251018
# mba_p         24.535952      22.555846      17.272020      16.886973
# salary    901754.893936  763359.777657  465131.504238  384234.419257
#
#                   mba_p        salary
# ssc_p         24.535952  9.017549e+05
# hsc_p         22.555846  7.633598e+05
# degree_p      17.272020  4.651315e+05
# etest_p       16.886973  3.842344e+05
# mba_p         34.028376  1.262455e+05
# salary    126245.485547  2.395714e+10

# %%
import matplotlib.pyplot as plt  
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.pairplot(dataset)
plt.show()

# %%
import matplotlib.pyplot as plt  
import seaborn as sns
plt.figure(figsize=(10, 5))
plt.scatter(dataset['degree_p'], dataset['etest_p'])
plt.title("Covariance of degree pass and entrance test pass")
plt.xlabel("degree")
plt.ylabel("entrance")
plt.show()

# %% [markdown]
# Covariance between degree pass and entrance pass
# --> 21.92 is an cov of degree_p and e_test - it have neutral covariance.
# Covariance between entrance pass and mbaa pass
# --> 17.27202 is an cov of e_test and degree_p - it have +ve covariance.

# %%
corr_matrix=dataset.corr()

# %%
import seaborn as sns
plt.figure(figsize=(10, 4)) # fig sixe length breadth of boxes
sns.heatmap(corr_matrix, annot=True, cmap='RdBu', fmt=".2f", linewidths=0.5)# annot denotes the value inside the box
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [raw]
# Sequential colormaps: These colormaps vary smoothly from low to high values. They are suitable for representing ordered data with a clear progression, such as heatmaps showing correlations or gradients.
#
# Examples: 'viridis', 'plasma', 'inferno', 'magma', 'cividis'
# Diverging colormaps: These colormaps have a distinct midpoint, with colors diverging on either side. They are useful for emphasizing deviations from a central value.
#
# Examples: 'coolwarm', 'RdBu', 'seismic'
# Qualitative colormaps: These colormaps are suited for categorical or discrete data. They have distinct colors that are easily distinguishable.
#
# Examples: 'tab10', 'Pastel1', 'Set3'

# %% [markdown]
# Correlation between mba_p and salary
#
# --> 0.13 is an correlation for mba pass and salary its a positive cor but not a good degree value
